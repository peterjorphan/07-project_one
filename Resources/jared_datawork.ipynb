# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
file = "../output/weather.csv"
df = pd.read_csv(file)
df
# Out:
#       Unnamed: 0                                   Trip ID  \
# 0              0  bc6f08423e9f194cb63a0d5ec6c6a2dea001e914
# 1              1  b2e0ede2b0d907551beda4e8b4b83c143010f63d
# 2              2  c2155aedc41a27673cd498d0fea754a18132d7f9
# 3              3  c1e860354f05150021e1bdeb7696314ca3e15608
# 4              4  bdff93a935333338e6f2f04f778ad7713a36c9ad
# 5              5  be7313b87f53e20b46020458e7b019c58f80b223
# 6              6  b08cec8ff3328356d388071edbfcf3f0405edfc6
# 7              7  c189e7f30cc51e0eb24c7ddbf6d4c9adbdd9f2a7
# 8              8  bc486809fdc9602698d026865cbfffafccbc0d11
# 9              9  b40db62cca32924d1b26ee28ea29b5dab6ccb242
# 10            10  c200c2db3839e47997cf9fb7b18beb792c0d931a
# 11            11  bfbea0ad4dd6bd17c0ee4dfd5609eec8109d7955
# 12            12  bb0f39973c72dfd3e11adbcd4fdfdd67d38f2bed
# 13            13  b4829b714d09aecc90a6711ad21fda8719a2f166
# 14            14  be172a6f93ca9d56058c1f9fc7b8eeeb42089127
# ...

# %%
# df['New Start'] = df['Trip Start Timestamp'].str.split(pat=None, expand=True, n=-1)
# df['Trip Start Timestamp'].str.split(' ', -1, expand=True)
df[['new time', 'time']] = df['time'].str.split('T', n=1, expand=True)
df.head()
# Out:
#    Unnamed: 0                                   Trip ID      time  \
# 0           0  bc6f08423e9f194cb63a0d5ec6c6a2dea001e914  01:45:00
# 1           1  b2e0ede2b0d907551beda4e8b4b83c143010f63d  04:45:00
# 2           2  c2155aedc41a27673cd498d0fea754a18132d7f9  07:15:00
# 3           3  c1e860354f05150021e1bdeb7696314ca3e15608  09:00:00
# 4           4  bdff93a935333338e6f2f04f778ad7713a36c9ad  04:15:00
#
#          summary  precipIntensity  precipProbability  temperature  \
# 0  Partly Cloudy           0.0000               0.00        43.39
# 1       Overcast           0.0005               0.14        53.40
# 2  Mostly Cloudy           0.0000               0.00         7.20
# 3          Clear           0.0000               0.00         5.96
# 4          Clear           0.0000               0.00        43.05
#
#    apparentTemperature  windSpeed                 icon    new time
# 0                40.05       5.59  partly-cloudy-night  2013-11-16
# ...

# %%
# df1 = df.groupby(['summary', 'new time'])['Trip ID'].count()
df1 = df.groupby(['summary', 'new time'], as_index=False).agg({'Trip ID': 'count', 'precipIntensity': 'mean', 'precipProbability': 'mean', 'temperature': 'mean', 'apparentTemperature': 'mean', 'windSpeed': 'mean'})
df1.to_csv('../output/summary_df.csv')
df1.head()
# Out:
#   summary    new time  Trip ID  precipIntensity  precipProbability  \
# 0   Clear  2013-01-02        1              0.0                0.0
# 1   Clear  2013-01-04        6              0.0                0.0
# 2   Clear  2013-01-05        1              0.0                0.0
# 3   Clear  2013-01-07        2              0.0                0.0
# 4   Clear  2013-01-09        1              0.0                0.0
#
#    temperature  apparentTemperature  windSpeed
# 0    11.490000            11.490000   2.550000
# 1    17.561667             8.576667   6.521667
# 2    22.900000            22.900000   2.670000
# 3    21.915000            15.160000   5.065000
# 4    36.650000            31.340000   6.630000

# %%
df2 = df1.groupby(['summary'], as_index=False).agg({'Trip ID': 'mean', 'precipIntensity': 'mean', 'precipProbability': 'mean', 'temperature': 'mean', 'apparentTemperature': 'mean', 'windSpeed': 'mean'})
df2.to_csv('../output/summary_mean_totals.csv')
df2.head()
# Out:
#       summary   Trip ID  precipIntensity  precipProbability  temperature  \
# 0       Clear  2.728551         0.000014           0.002020    47.423988
# 1     Drizzle  1.474074         0.008782           0.556931    54.859182
# 2    Flurries  1.714286         0.003646           0.418929    32.431786
# 3       Foggy  2.168831         0.000225           0.029229    38.642200
# 4  Heavy Rain  1.500000         0.259375           0.950000    61.355000
#
#    apparentTemperature  windSpeed
# 0            46.040929   2.814282
# 1            53.911053   3.796320
# 2            28.987143   4.503214
# 3            36.126597   3.396877
# 4            62.025000   2.440000

# %%
fig, ax = plt.subplots()
plt.scatter(df2['windSpeed'], df2['precipIntensity'], s=df2['Trip ID']*100, c='gold', alpha=.7, linewidths=None, edgecolors='black')

plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
ax.grid()

# %%
# df2.to_csv('summary_mean_totals.csv')

# %%
# df_com = df.groupby(['Community Areas'], as_index=False).agg({'Trip Seconds': 'mean', 'Trip Miles': 'mean', 'Trip Total': 'mean', 'Trip ID': 'count'})
# df_com.head()

# %%
# newdatestart_list = []

# for date in df['Trip Start Timestamp']:
#     date_obj = datetime.strptime(date, '%m/%d/%Y %H:%M:%S %p')
#     new_date = date_obj.strftime('%Y-%m-%dT%H:%M:%S')
#     newdatestart_list.append(new_date)

# df['Trip Start Timestamp'] = newdatestart_list
# df.head()

# for date in df['Trip End Timestamp']:
#     print(type(date))
#     date_obj = datetime.strptime(date, '%m/%d/%Y %H:%M:%S %p')
#     new_date = date_obj.strftime('%Y-%m-%dT%H:%M:%S')
#     newdateend_list.append(new_date)
