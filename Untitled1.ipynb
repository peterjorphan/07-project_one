# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
file = "./output/master_no_grouping.csv"
df = pd.read_csv(file)
df
# Out:
#       Unnamed: 0                                   Trip ID      time  \
# 0              0  bc6f08423e9f194cb63a0d5ec6c6a2dea001e914  01:45:00
# 1              1  b2e0ede2b0d907551beda4e8b4b83c143010f63d  04:45:00
# 2              2  c2155aedc41a27673cd498d0fea754a18132d7f9  07:15:00
# 3              3  c1e860354f05150021e1bdeb7696314ca3e15608  09:00:00
# 4              4  bdff93a935333338e6f2f04f778ad7713a36c9ad  04:15:00
# 5              5  be7313b87f53e20b46020458e7b019c58f80b223  09:30:00
# 6              6  b08cec8ff3328356d388071edbfcf3f0405edfc6  06:45:00
# 7              7  c189e7f30cc51e0eb24c7ddbf6d4c9adbdd9f2a7  11:45:00
# 8              8  bc486809fdc9602698d026865cbfffafccbc0d11  02:15:00
# 9              9  b40db62cca32924d1b26ee28ea29b5dab6ccb242  10:45:00
# 10            10  c200c2db3839e47997cf9fb7b18beb792c0d931a  01:00:00
# 11            11  bfbea0ad4dd6bd17c0ee4dfd5609eec8109d7955  08:30:00
# 12            12  bb0f39973c72dfd3e11adbcd4fdfdd67d38f2bed  05:00:00
# ...

# %%
file = './output/groupby_high_mid_low_freezing.csv'
df1 = pd.read_csv(file)
df1
# Out:
#   temp range  Trip ID  precipIntensity  precipProbability  temperature  \
# 0   Freezing     2141         0.000552           0.023975    23.029743
# 1   High 90+       51         0.000000           0.000000    87.183529
# 2  Low 33-49     1830         0.003018           0.102831    42.784109
# 3  Mid 50-89     3820         0.003642           0.072890    65.206822
#
#    apparentTemperature  windSpeed  Trip Seconds  Trip Miles       Fare  \
# 0            18.021532   4.645339    723.231057    2.481429  11.455222
# 1            93.792549   3.449216    961.176471    2.227647  15.837451
# 2            40.985792   3.795891    781.623838    3.236459  12.327262
# 3            65.587141   2.815911    810.388743    3.087403  12.509223
#
#    Trip Total
# 0   13.286861
# 1   18.652745
# 2   14.608508
# 3   14.600746

# %%
file = './output/df7.csv'
df7 = pd.read_csv(file)
df7
# Out:
#       Unnamed: 0                                   Trip ID      time  \
# 0              0  bc6f08423e9f194cb63a0d5ec6c6a2dea001e914  01:45:00
# 1              1  b2e0ede2b0d907551beda4e8b4b83c143010f63d  04:45:00
# 2              2  c2155aedc41a27673cd498d0fea754a18132d7f9  07:15:00
# 3              3  c1e860354f05150021e1bdeb7696314ca3e15608  09:00:00
# 4              4  bdff93a935333338e6f2f04f778ad7713a36c9ad  04:15:00
# 5              5  be7313b87f53e20b46020458e7b019c58f80b223  09:30:00
# 6              6  b08cec8ff3328356d388071edbfcf3f0405edfc6  06:45:00
# 7              7  c189e7f30cc51e0eb24c7ddbf6d4c9adbdd9f2a7  11:45:00
# 8              8  bc486809fdc9602698d026865cbfffafccbc0d11  02:15:00
# 9              9  b40db62cca32924d1b26ee28ea29b5dab6ccb242  10:45:00
# 10            10  c200c2db3839e47997cf9fb7b18beb792c0d931a  01:00:00
# 11            11  bfbea0ad4dd6bd17c0ee4dfd5609eec8109d7955  08:30:00
# 12            12  bb0f39973c72dfd3e11adbcd4fdfdd67d38f2bed  05:00:00
# ...

# %%
df_freezing = df7.loc[df7['apparentTemperature'] < 33]
df_freezing.head()
# Out:
#     Unnamed: 0                                   Trip ID      time  \
# 2            2  c2155aedc41a27673cd498d0fea754a18132d7f9  07:15:00
# 3            3  c1e860354f05150021e1bdeb7696314ca3e15608  09:00:00
# 7            7  c189e7f30cc51e0eb24c7ddbf6d4c9adbdd9f2a7  11:45:00
# 13          13  b4829b714d09aecc90a6711ad21fda8719a2f166  10:00:00
# 14          14  be172a6f93ca9d56058c1f9fc7b8eeeb42089127  07:45:00
#
#           summary  precipIntensity  precipProbability  temperature  \
# 2   Mostly Cloudy              0.0                0.0         7.20
# 3           Clear              0.0                0.0         5.96
# 7   Partly Cloudy              0.0                0.0        29.46
# 13  Mostly Cloudy              0.0                0.0         9.66
# 14       Overcast              0.0                0.0         2.78
#
#     apparentTemperature  windSpeed           icon     ...       Fare  Tips  \
# 2                 -4.92       7.53  partly cloudy     ...       8.44  0.00
# ...

# %%
df_snow = df.loc[df['icon'] == 'snow']
df_snow.head()
# Out:
#       Unnamed: 0                                   Trip ID      time  \
# 774          774  b62876c0cb364b9c36f20840c743f4e06e35c38e  12:45:00
# 864          864  c2c9149e85015d95e1aa1b16e95f3a2155f36e8f  11:45:00
# 1383        1383  b7c7feb6e6fac1389db7919fa37f4554c11391c2  12:45:00
# 1532        1532  b1d0e56b2486bd385111a48fe9e663ed8ff806b8  04:30:00
# 1670        1670  bd291a2add0d91c992e93704f3150d9251b5e4c3  06:30:00
#
#          summary  precipIntensity  precipProbability  temperature  \
# 774   Light Snow           0.0132               0.62        34.24
# 864   Light Snow           0.0124               0.41        33.39
# 1383    Flurries           0.0025               0.36        32.32
# 1532    Flurries           0.0021               0.36        34.89
# 1670  Light Snow           0.0118               0.76        34.39
#
#       apparentTemperature  windSpeed  icon     ...     Pickup Community Area  \
# ...

# %%
df_other = df.loc[df['icon'] != 'snow']
df_other.head()
# Out:
#    Unnamed: 0                                   Trip ID      time  \
# 0           0  bc6f08423e9f194cb63a0d5ec6c6a2dea001e914  01:45:00
# 1           1  b2e0ede2b0d907551beda4e8b4b83c143010f63d  04:45:00
# 2           2  c2155aedc41a27673cd498d0fea754a18132d7f9  07:15:00
# 3           3  c1e860354f05150021e1bdeb7696314ca3e15608  09:00:00
# 4           4  bdff93a935333338e6f2f04f778ad7713a36c9ad  04:15:00
#
#          summary  precipIntensity  precipProbability  temperature  \
# 0  Partly Cloudy           0.0000               0.00        43.39
# 1       Overcast           0.0005               0.14        53.40
# 2  Mostly Cloudy           0.0000               0.00         7.20
# 3          Clear           0.0000               0.00         5.96
# 4          Clear           0.0000               0.00        43.05
#
#    apparentTemperature  windSpeed                 icon     ...      \
# 0                40.05       5.59  partly-cloudy-night     ...
# ...

# %%
df_snow.columns
# Out:
# Index(['Unnamed: 0', 'Trip ID', 'time', 'summary', 'precipIntensity',
#        'precipProbability', 'temperature', 'apparentTemperature', 'windSpeed',
#        'icon', 'Taxi ID', 'Trip Start Timestamp', 'Trip End Timestamp',
#        'Trip Seconds', 'Trip Miles', 'Pickup Community Area', 'Fare', 'Tips',
#        'Tolls', 'Extras', 'Trip Total', 'Payment Type',
#        'Pickup Centroid Latitude', 'Pickup Centroid Longitude', 'day'],
#       dtype='object')

# %%
x = df_freezing['Trip Miles']
y = df_freezing['apparentTemperature']
s = df_freezing['Trip Seconds']

colors = 'blue'
# area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=s/100, c=colors, alpha=0.5)
plt.show()

# %%
x = df_snow['Trip Miles']
y = df_snow['apparentTemperature']
s = df_snow['Trip Seconds']
# c = 'blue'

colors = 'blue'
# area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=s/100, c=colors, alpha=0.5)
plt.show()

# %%
x = df_snow['Trip Miles']
y = df_snow['apparentTemperature']
s = df_snow['windSpeed']
# c = 'blue'

colors = 'blue'
# area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=s*10, c=colors, alpha=0.5)
plt.show()
